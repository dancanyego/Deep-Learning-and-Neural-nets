# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings

warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
## Creating a sine wave with numpy

# %%
x = np.linspace(0,60,501)
y = np.sin(x)

# %%
plt.plot(x,y)
